# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm

# %%
# Define target url. Search for houses in Copenhagen and surroundings, boligtype = Rent
url = "https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/"
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text,'html.parser')

# %% [markdown]
# # Get pagination links

# %%
# There are 153 pages, starting from index page 1
pagination_html = soup.find('div',{'class':'css-95dbty'}).find_all('button',{'class':'temporaryButtonClassname'})
for i in range(len(pagination_html)):
    print(pagination_html[i].get_text())
# Out:
# 1
# 2
# 3
# 4
# 5
# 153

# %%
# We can see that when we choose the 2nd page then the offset attribute in the url changes 2nd page -> offset = 18 (or [2-1]*18,
# 3rd page -> offset = 36 (or [3-1]*18) etc)

# %%
links_of_pages = []
for i in range(1,int(pagination_html[-1].get_text())+1):
    if i == 1:
        links_of_pages.append('https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/')
    else:
        links_of_pages.append('https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset={}'.format((i-1)*18))

# %%
links_of_pages
# Out:
# ['https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=18',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=36',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=54',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=72',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=90',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=108',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=126',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=144',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=162',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=180',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=198',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=216',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=234',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=252',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=270',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=288',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=306',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=324',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=342',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=360',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=378',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=396',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=414',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=432',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=450',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=468',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=486',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=504',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=522',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=540',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=558',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=576',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=594',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=612',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=630',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=648',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=666',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=684',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=702',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=720',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=738',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=756',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=774',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=792',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=810',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=828',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=846',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=864',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=882',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=900',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=918',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=936',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=954',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=972',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=990',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1008',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1026',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1044',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1062',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1080',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1098',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1116',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1134',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1152',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1170',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1188',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1206',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1224',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1242',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1260',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1278',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1296',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1314',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1332',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1350',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1368',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1386',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1404',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1422',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1440',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1458',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1476',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1494',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1512',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1530',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1548',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1566',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1584',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1602',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1620',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1638',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1656',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1674',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1692',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1710',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1728',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1746',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1764',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1782',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1800',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1818',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1836',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1854',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1872',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1890',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1908',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1926',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1944',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1962',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1980',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1998',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2016',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2034',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2052',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2070',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2088',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2106',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2124',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2142',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2160',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2178',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2196',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2214',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2232',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2250',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2268',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2286',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2304',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2322',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2340',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2358',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2376',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2394',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2412',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2430',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2448',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2466',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2484',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2502',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2520',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2538',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2556',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2574',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2592',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2610',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2628',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2646',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2664',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2682',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2700',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2718',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=2736']

# %% [markdown]
# # Get links of ads in first page

# %%
# first page contains 18 ads 
first_page_ads = soup.find_all('div',{'class':'css-7r8xmo'})[1].find_all('div',{'class':'temporaryFlexColumnClassName css-nkly31'})
len(first_page_ads)
# Out:
# 18

# %%
soup.find_all('div',{'class':'css-7r8xmo'})[1].find_all('div',{'class':'temporaryFlexColumnClassName css-nkly31'})[0].find('div',{'class':'css-m2wmpr'}).find('a')['href']
# Out:
# '/en/rental-apartments/k%C3%B8benhavn/113m2-3-room-id-5427608'

# %%
first_page_links = []
for i in range(len(first_page_ads)):
    first_page_links.append('https://www.boligportal.dk{}'.format(first_page_ads[i].find('div',{'class':'css-m2wmpr'}).find('a')['href']))

# %%
first_page_links
# Out:
# ['https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/113m2-3-room-id-5427608',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/96m2-2-room-id-5427607',
#  'https://www.boligportal.dk/en/rental-rooms/k%C3%B8benhavn/7m2-1-room-id-5427192',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/117m2-4-room-id-5427605',
#  'https://www.boligportal.dk/en/rental-rooms/k%C3%B8benhavn/13m2-1-room-id-1556517',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/111m2-4-room-id-4651675',
#  'https://www.boligportal.dk/en/rental-rooms/k%C3%B8benhavn/12m2-1-room-id-5427287',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/102m2-2-room-id-5223900',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/42m2-1-room-id-5427588',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/84m2-2-room-id-5427586',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/127m2-4-room-id-5258148',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/106m2-5-room-id-5229303',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/123m2-3-room-id-5383014',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/28m2-1-room-id-5427569',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/31m2-1-room-id-5236563',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/125m2-4-room-id-5406526',
#  'https://www.boligportal.dk/en/rental-houses/k%C3%B8benhavn/90m2-3-room-id-5332510',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/87m2-3-room-id-5427557']

# %% [markdown]
# # Lets get the links of all ads across all pages

# %%
# So, now we have to iterate through links_of_pages list, connect to each link and get its links.

# %%
all_ads_links = []
for link in tqdm(links_of_pages):
    url = link
    response = requests.get(url)
    soup = BeautifulSoup(response.text,'html.parser')
    page_ads = soup.find_all('div',{'class':'css-7r8xmo'})[1].find_all('div',{'class':'temporaryFlexColumnClassName css-nkly31'})
    for i in range(len(page_ads)):
        all_ads_links.append('https://www.boligportal.dk{}'.format(page_ads[i].find('div',{'class':'css-m2wmpr'}).find('a')['href']))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 153/153 [01:32<00:00,  1.65it/s]

# %%
len(all_ads_links)
# Out:
# 2741

# %% [markdown]
# # Get data

# %%
# Now I have to connect to each link from above and get the data that I need. 
# Store them in a dictionary and append them in a list . 
# Should look like this [{home1:id},{home2:id}, etc]

# %%
#########

# %%
url = "https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/96m2-2-room-id-5427607"
response = requests.get(url)
soup = BeautifulSoup(response.text,'html.parser')

# %%
# adress
soup.find_all('div',{'class':'css-1gjufnd'})[0].find('div',{'class':'css-o9y6d5'}).get_text()
# Out:
# 'Nordmarks Alle, 2620 København, Albertslund  - 2nd floor'

# %%
# About property 
about_property = soup.find_all('section',{'class':'css-6tqm96'})[0]

# %%
# Property tpy
about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[0].find('div',{'class':'css-6tqm96'}).get_text()
# Out:
# 'Property type'

# %%
about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[0].find('div',{'class':'css-5fqrc1'}).get_text()
# Out:
# 'Apartment'

# %%
lst1 = []
lst2 = []
for i in range(len(about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'}))):
    lst1.append(about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-6tqm96'}).get_text())
    lst2.append(about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-5fqrc1'}).get_text())
    new = dict(zip(lst1,lst2))

# %%
new
# Out:
# {'Property type': 'Apartment',
#  'Size': '96 m²',
#  'Rooms': '2',
#  'Floor': '2nd ',
#  'Furnished': 'No',
#  'Shareable': 'No',
#  'Pets allowed': 'Yes',
#  'Elevator': 'Yes',
#  'Senior friendly': 'Not specified',
#  'Students only': 'Not specified',
#  'Balcony': 'Yes',
#  'Parking': 'Not specified',
#  'Dishwasher': 'Not specified',
#  'Washing machine': 'Not specified',
#  'Electric charging station': 'No',
#  'Dryer': 'Not specified',
#  'Energy rating': '-'}

# %%
# About rental 
about_rental = soup.find_all('section',{'class':'css-6tqm96'})[1]

# %%
about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[0].find('div',{'class':'css-6tqm96'}).get_text()
# Out:
# 'Rental period'

# %%
about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[0].find('div',{'class':'css-5fqrc1'}).get_text()
# Out:
# 'Unlimited'

# %%
lst2 = []
lst3 = []
for i in range(len(about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'}))):
    lst2.append(about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-6tqm96'}).get_text())
    lst3.append(about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-5fqrc1'}).get_text())
    new1 = dict(zip(lst2,lst3))

# %%
new1
# Out:
# {'Rental period': 'Unlimited',
#  'Available from': 'As soon as possible',
#  'Monthly net rent': '12.400 kr.',
#  'Deposit': '37.200 kr.',
#  'Prepaid rent': '12.400 kr.',
#  'Move-in price': '62.000 kr.',
#  'Creation Date': '21/03/2024',
#  'Listing-id': '5427607'}

# %%
new.update(new1)

# %%
new['Adress'] = soup.find_all('div',{'class':'css-1gjufnd'})[0].find('div',{'class':'css-o9y6d5'}).get_text()

# %%
new
# Out:
# {'Property type': 'Apartment',
#  'Size': '96 m²',
#  'Rooms': '2',
#  'Floor': '2nd ',
#  'Furnished': 'No',
#  'Shareable': 'No',
#  'Pets allowed': 'Yes',
#  'Elevator': 'Yes',
#  'Senior friendly': 'Not specified',
#  'Students only': 'Not specified',
#  'Balcony': 'Yes',
#  'Parking': 'Not specified',
#  'Dishwasher': 'Not specified',
#  'Washing machine': 'Not specified',
#  'Electric charging station': 'No',
#  'Dryer': 'Not specified',
#  'Energy rating': '-',
#  'Rental period': 'Unlimited',
#  'Available from': 'As soon as possible',
#  'Monthly net rent': '12.400 kr.',
#  'Deposit': '37.200 kr.',
#  'Prepaid rent': '12.400 kr.',
#  'Move-in price': '62.000 kr.',
#  'Creation Date': '21/03/2024',
#  'Listing-id': '5427607',
#  'Adress': 'Nordmarks Alle, 2620 København, Albertslund  - 2nd floor'}

# %%
# Now I have to connect to each link from above and get the data that I need. 
# Store them in a dictionary and append them in a list . 
# Should look like this [{home1:id},{home2:id}, etc]

# %%
def get_data(link):
    prop_key = []
    prop_value = []
    rental_key = []
    rental_value = []
    properties = {}
    rental_features = {}
    
    url = link
    response = requests.get(url)
    soup = BeautifulSoup(response.text,'html.parser')
    about_property = soup.find_all('section',{'class':'css-6tqm96'})[0]
    about_rental = soup.find_all('section',{'class':'css-6tqm96'})[1]

    for i in range(len(about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'}))):
        prop_key.append(about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-6tqm96'}).get_text())
        prop_value.append(about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-5fqrc1'}).get_text())
        properties = dict(zip(prop_key,prop_value))

    for i in range(len(about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'}))):
        rental_key.append(about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-6tqm96'}).get_text())
        rental_value.append(about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-5fqrc1'}).get_text())
        rental_features = dict(zip(rental_key,rental_value))
    properties.update(rental_features)
    properties['Adress'] = soup.find_all('div',{'class':'css-1gjufnd'})[0].find('div',{'class':'css-o9y6d5'}).get_text()
    return properties

# %%
data = [] 
for link in tqdm(all_ads_links):
    data.append(get_data(link))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2741/2741 [20:00<00:00,  2.28it/s]

# %%
data
# Out:
# [{'Property type': 'Apartment',
#   'Size': '100 m²',
#   'Rooms': '4',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '',
#   'Rental period': '1-11 months',
#   'Available from': '1 September 2024',
#   'Monthly net rent': '22.000 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '22.000 kr.',
#   'Prepaid rent': '22.000 kr.',
#   'Move-in price': '66.000 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427722',
#   'Adress': 'Løgstørgade, 2100 København, København Ø  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '154 m²',
#   'Rooms': '5',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 May 2024',
#   'Monthly net rent': '23.000 kr.',
#   'Utilities': '1.400 kr.',
#   'Deposit': '69.000 kr.',
#   'Prepaid rent': '69.000 kr.',
#   'Move-in price': '162.400 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427716',
#   'Adress': 'Virginiavej, 2000 København, Frederiksberg  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '54 m²',
#   'Rooms': '2',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '8.448 kr.',
#   'Utilities': '410 kr.',
#   'Deposit': '25.344 kr.',
#   'Prepaid rent': '25.344 kr.',
#   'Move-in price': '59.546 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427711',
#   'Adress': 'Ellensvej, 2920 København, Charlottenlund  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '71 m²',
#   'Rooms': '3',
#   'Floor': '5th ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '14.300 kr.',
#   'Utilities': '700 kr.',
#   'Deposit': '42.900 kr.',
#   'Prepaid rent': '14.300 kr.',
#   'Move-in price': '72.200 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427710',
#   'Adress': 'Martha Christensens Vej, 2300 København, København S  - 5th floor'},
#  {'Property type': 'Apartment',
#   'Size': '63 m²',
#   'Rooms': '2',
#   'Floor': '4th ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '12.700 kr.',
#   'Utilities': '650 kr.',
#   'Deposit': '38.100 kr.',
#   'Prepaid rent': '12.700 kr.',
#   'Move-in price': '64.150 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427709',
#   'Adress': 'Martha Christensens Vej, 2300 København, København S  - 4th floor'},
#  {'Property type': 'Apartment',
#   'Size': '49 m²',
#   'Rooms': '2',
#   'Floor': '6th ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '13.000 kr.',
#   'Utilities': '600 kr.',
#   'Deposit': '39.000 kr.',
#   'Prepaid rent': '13.000 kr.',
#   'Move-in price': '65.600 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427708',
#   'Adress': 'Martha Christensens Vej, 2300 København, København S  - 6th floor'},
#  {'Property type': 'Apartment',
#   'Size': '110 m²',
#   'Rooms': '4',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '',
#   'Rental period': '24+ months',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '15.500 kr.',
#   'Utilities': '1.500 kr.',
#   'Deposit': '31.000 kr.',
#   'Prepaid rent': '15.500 kr.',
#   'Move-in price': '63.500 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5395702',
#   'Adress': 'Frankrigsgade, 2300 København, København S  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '94 m²',
#   'Rooms': '3',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '13.062 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '39.186 kr.',
#   'Prepaid rent': '13.062 kr.',
#   'Move-in price': '66.110 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5074207',
#   'Adress': 'Centrumgaden, 2750 København, Ballerup  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '85 m²',
#   'Rooms': '2',
#   'Floor': '5th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '13.150 kr.',
#   'Utilities': '700 kr.',
#   'Deposit': '39.450 kr.',
#   'Prepaid rent': '13.150 kr.',
#   'Move-in price': '66.450 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427612',
#   'Adress': 'Axel Heides Gade, 2300 København, København S  - 5th floor'},
#  {'Property type': 'Apartment',
#   'Size': '86 m²',
#   'Rooms': '3',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 May 2024',
#   'Monthly net rent': '12.150 kr.',
#   'Utilities': '1.440 kr.',
#   'Deposit': '36.450 kr.',
#   'Prepaid rent': '36.450 kr.',
#   'Move-in price': '86.490 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427611',
#   'Adress': 'Kongevejen, 2830 København, Virum  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '113 m²',
#   'Rooms': '3',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'Not specified',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'No',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '13.400 kr.',
#   'Deposit': '40.200 kr.',
#   'Prepaid rent': '13.400 kr.',
#   'Move-in price': '67.000 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427608',
#   'Adress': 'Nordmarks Alle, 2620 København, Albertslund  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '96 m²',
#   'Rooms': '2',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'Not specified',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'No',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '12.400 kr.',
#   'Deposit': '37.200 kr.',
#   'Prepaid rent': '12.400 kr.',
#   'Move-in price': '62.000 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427607',
#   'Adress': 'Nordmarks Alle, 2620 København, Albertslund  - 2nd floor'},
#  {'Property type': 'Room',
#   'Size': '7 m²',
#   'Rooms': '1',
#   'Floor': '1st ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 April 2024',
#   'Monthly net rent': '4.200 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '5.000 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '9.200 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427192',
#   'Adress': 'Holmbladsgade, 2300 København, København S  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '117 m²',
#   'Rooms': '4',
#   'Floor': '4th ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '31 March 2024',
#   'Monthly net rent': '14.500 kr.',
#   'Utilities': '1.350 kr.',
#   'Deposit': '43.500 kr.',
#   'Prepaid rent': '14.500 kr.',
#   'Move-in price': '73.850 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427605',
#   'Adress': 'Margrethevænget, 2665 København, Vallensbæk Strand  - 4th floor'},
#  {'Property type': 'Room',
#   'Size': '13 m²',
#   'Rooms': '1',
#   'Floor': '-',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Not specified',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Not specified',
#   'Parking': 'Not specified',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 May 2024',
#   'Monthly net rent': '4.500 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '13.500 kr.',
#   'Prepaid rent': '4.500 kr.',
#   'Move-in price': '22.500 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '1556517',
#   'Adress': 'Runebergs Alle, 2860 København, Søborg '},
#  {'Property type': 'Apartment',
#   'Size': '111 m²',
#   'Rooms': '4',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'No',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '16.188 kr.',
#   'Utilities': '900 kr.',
#   'Deposit': '48.564 kr.',
#   'Prepaid rent': '48.564 kr.',
#   'Move-in price': '114.216 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '4651675',
#   'Adress': 'Godthåbsvej, 2000 København, Frederiksberg  - 2nd floor'},
#  {'Property type': 'Room',
#   'Size': '12 m²',
#   'Rooms': '1',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': '12-23 months',
#   'Available from': '1 April 2024',
#   'Monthly net rent': '6.000 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '18.000 kr.',
#   'Prepaid rent': '6.000 kr.',
#   'Move-in price': '30.000 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427287',
#   'Adress': 'Lyngbyvej, 2100 København, København Ø  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '102 m²',
#   'Rooms': '2',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '19.500 kr.',
#   'Utilities': '1.200 kr.',
#   'Deposit': '58.500 kr.',
#   'Prepaid rent': '19.500 kr.',
#   'Move-in price': '98.700 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5223900',
#   'Adress': 'Løvstræde, 1152 København, København K  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '42 m²',
#   'Rooms': '1',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '8.850 kr.',
#   'Utilities': '400 kr.',
#   'Deposit': '26.550 kr.',
#   'Prepaid rent': '8.850 kr.',
#   'Move-in price': '44.650 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427588',
#   'Adress': 'Hermodsgade, 2200 København, København N  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '84 m²',
#   'Rooms': '2',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '15.950 kr.',
#   'Utilities': '910 kr.',
#   'Deposit': '47.850 kr.',
#   'Prepaid rent': '15.950 kr.',
#   'Move-in price': '80.660 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427586',
#   'Adress': 'Amerika Plads, 2100 København, København Ø  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '127 m²',
#   'Rooms': '4',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '17.950 kr.',
#   'Utilities': '1.470 kr.',
#   'Deposit': '53.850 kr.',
#   'Prepaid rent': '17.950 kr.',
#   'Move-in price': '91.220 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5258148',
#   'Adress': 'Artillerivej, 2300 København, København S  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '106 m²',
#   'Rooms': '5',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'No',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '16.600 kr.',
#   'Utilities': '1.200 kr.',
#   'Deposit': '49.800 kr.',
#   'Prepaid rent': '16.600 kr.',
#   'Move-in price': '84.200 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5229303',
#   'Adress': 'Richard Mortensens Vej, 2300 København, København S  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '123 m²',
#   'Rooms': '3',
#   'Floor': '4th ',
#   'Furnished': 'Yes',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': '12-23 months',
#   'Available from': '1 April 2024',
#   'Monthly net rent': '18.900 kr.',
#   'Utilities': '1.250 kr.',
#   'Deposit': '56.700 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '76.850 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5383014',
#   'Adress': 'Dyrkøb, 1166 København, København K  - 4th floor'},
#  {'Property type': 'Apartment',
#   'Size': '28 m²',
#   'Rooms': '1',
#   'Floor': '1st ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '30 April 2024',
#   'Monthly net rent': '9.000 kr.',
#   'Utilities': '400 kr.',
#   'Deposit': '9.000 kr.',
#   'Prepaid rent': '27.000 kr.',
#   'Move-in price': '45.400 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427569',
#   'Adress': 'Njalsgade, 2300 København, København S  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '31 m²',
#   'Rooms': '1',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '30 April 2024',
#   'Monthly net rent': '7.800 kr.',
#   'Utilities': '750 kr.',
#   'Deposit': '23.400 kr.',
#   'Prepaid rent': '7.800 kr.',
#   'Move-in price': '39.750 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5236563',
#   'Adress': 'Vanløse Allé, 2720 København, Vanløse  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '125 m²',
#   'Rooms': '4',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Not specified',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Not specified',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 April 2024',
#   'Monthly net rent': '18.995 kr.',
#   'Utilities': '450 kr.',
#   'Deposit': '56.985 kr.',
#   'Prepaid rent': '18.995 kr.',
#   'Move-in price': '95.425 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5406526',
#   'Adress': 'Karen Schacks Vej, 2800 København, Kongens Lyngby  - 1st floor'},
#  {'Property type': 'House',
#   'Size': '90 m²',
#   'Rooms': '3',
#   'Floor': '-',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'No',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': '1-11 months',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '17.900 kr.',
#   'Utilities': '3.140 kr.',
#   'Deposit': '53.700 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '74.740 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5332510',
#   'Adress': 'Holmevej, 2860 København, Søborg '},
#  {'Property type': 'Townhouse',
#   'Size': '140 m²',
#   'Rooms': '5',
#   'Floor': '-',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'No',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '18.490 kr.',
#   'Utilities': '1.200 kr.',
#   'Deposit': '55.470 kr.',
#   'Prepaid rent': '18.490 kr.',
#   'Move-in price': '93.650 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427549',
#   'Adress': 'Lykkens Minde, 2860 København, Søborg '},
#  {'Property type': 'Apartment',
#   'Size': '90 m²',
#   'Rooms': '3',
#   'Floor': '6th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '12.200 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '36.600 kr.',
#   'Prepaid rent': '12.200 kr.',
#   'Move-in price': '62.000 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427547',
#   'Adress': 'Bornholms Allé, 2630 København, Taastrup  - 6th floor'},
#  {'Property type': 'Apartment',
#   'Size': '85 m²',
#   'Rooms': '3',
#   'Floor': '6th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '12.000 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '36.000 kr.',
#   'Prepaid rent': '12.000 kr.',
#   'Move-in price': '61.000 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427546',
#   'Adress': 'Høje Taastrup Boulevard, 2630 København, Taastrup  - 6th floor'},
#  {'Property type': 'Apartment',
#   'Size': '68 m²',
#   'Rooms': '2',
#   'Floor': '4th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '11.200 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '33.600 kr.',
#   'Prepaid rent': '11.200 kr.',
#   'Move-in price': '56.800 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427545',
#   'Adress': 'Bornholms Allé, 2630 København, Taastrup  - 4th floor'},
#  {'Property type': 'Apartment',
#   'Size': '79 m²',
#   'Rooms': '3',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '14 July 2024',
#   'Monthly net rent': '10.900 kr.',
#   'Utilities': '900 kr.',
#   'Deposit': '32.700 kr.',
#   'Prepaid rent': '10.900 kr.',
#   'Move-in price': '55.400 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427544',
#   'Adress': 'Spættevangen, 2635 København, Ishøj  - 2nd floor'},
#  {'Property type': 'Room',
#   'Size': '21 m²',
#   'Rooms': '1',
#   'Floor': '5th ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 May 2024',
#   'Monthly net rent': '7.000 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '21.000 kr.',
#   'Prepaid rent': '7.000 kr.',
#   'Move-in price': '35.000 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5409055',
#   'Adress': 'Store Kongensgade, 1264 København, København K  - 5th floor'},
#  {'Property type': 'Apartment',
#   'Size': '132 m²',
#   'Rooms': '5',
#   'Floor': '4th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Not specified',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Not specified',
#   'Parking': 'Not specified',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '16.500 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '49.500 kr.',
#   'Prepaid rent': '33.000 kr.',
#   'Move-in price': '99.800 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '4756361',
#   'Adress': 'Oldermandsvej, 2400 København, København NV  - 4th floor'},
#  {'Property type': 'Apartment',
#   'Size': '68 m²',
#   'Rooms': '2',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '8.925 kr.',
#   'Utilities': '700 kr.',
#   'Deposit': '26.775 kr.',
#   'Prepaid rent': '17.850 kr.',
#   'Move-in price': '54.250 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427538',
#   'Adress': 'Elmelundevej, 2700 København, Brønshøj  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '105 m²',
#   'Rooms': '3',
#   'Floor': '7th ',
#   'Furnished': 'Yes',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': '1-11 months',
#   'Available from': '15 April 2024',
#   'Monthly net rent': '21.000 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '4.200 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '26.200 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427532',
#   'Adress': 'Vester Søgade, 1601 København, København V  - 7th floor'},
#  {'Property type': 'Apartment',
#   'Size': '200 m²',
#   'Rooms': '5',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '26.600 kr.',
#   'Utilities': '1.500 kr.',
#   'Deposit': '76.800 kr.',
#   'Prepaid rent': '51.200 kr.',
#   'Move-in price': '156.100 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427529',
#   'Adress': 'Bülowsvej, 1870 København, Frederiksberg C  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '106 m²',
#   'Rooms': '4',
#   'Floor': '4th ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 May 2024',
#   'Monthly net rent': '13.800 kr.',
#   'Utilities': '1.300 kr.',
#   'Deposit': '41.400 kr.',
#   'Prepaid rent': '13.800 kr.',
#   'Move-in price': '70.300 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427430',
#   'Adress': 'Torbenfeldvej, 2665 København, Vallensbæk Strand  - 4th floor'},
#  {'Property type': 'Apartment',
#   'Size': '38 m²',
#   'Rooms': '1',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '9.675 kr.',
#   'Utilities': '550 kr.',
#   'Deposit': '29.025 kr.',
#   'Prepaid rent': '9.675 kr.',
#   'Move-in price': '48.925 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5348053',
#   'Adress': 'Øresundsvej, 2300 København, København S  - 2nd floor'},
#  {'Property type': 'Room',
#   'Size': '25 m²',
#   'Rooms': '1',
#   'Floor': '1st ',
#   'Furnished': 'Yes',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': '12-23 months',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '4.000 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '0 kr.',
#   'Prepaid rent': '4.000 kr.',
#   'Move-in price': '8.000 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427380',
#   'Adress': "Christian II's Allé, 2300 København, København S  - 1st floor"},
#  {'Property type': 'Room',
#   'Size': '13 m²',
#   'Rooms': '1',
#   'Floor': '5th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '5.500 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '11.000 kr.',
#   'Prepaid rent': '5.500 kr.',
#   'Move-in price': '22.000 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427357',
#   'Adress': 'Svinget, 2300 København, København S  - 5th floor'},
#  {'Property type': 'Apartment',
#   'Size': '98 m²',
#   'Rooms': '3',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Not specified',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '13.330 kr.',
#   'Deposit': '39.990 kr.',
#   'Prepaid rent': '13.330 kr.',
#   'Move-in price': '66.650 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427393',
#   'Adress': 'Skjeberg Allé, 2630 København, Taastrup  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '96 m²',
#   'Rooms': '3',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Not specified',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '13.585 kr.',
#   'Utilities': '500 kr.',
#   'Deposit': '40.755 kr.',
#   'Prepaid rent': '13.585 kr.',
#   'Move-in price': '68.425 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427392',
#   'Adress': 'Vestervej, 2630 København, Taastrup  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '81 m²',
#   'Rooms': '3',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Not specified',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '12.150 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '36.450 kr.',
#   'Prepaid rent': '12.150 kr.',
#   'Move-in price': '61.550 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427391',
#   'Adress': 'Lyskær, 2730 København, Herlev  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '86 m²',
#   'Rooms': '3',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '14 July 2024',
#   'Monthly net rent': '11.600 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '34.800 kr.',
#   'Prepaid rent': '11.600 kr.',
#   'Move-in price': '59.000 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427389',
#   'Adress': 'Spættevangen, 2635 København, Ishøj  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '82 m²',
#   'Rooms': '3',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '14 July 2024',
#   'Monthly net rent': '11.500 kr.',
#   'Utilities': '950 kr.',
#   'Deposit': '34.500 kr.',
#   'Prepaid rent': '11.500 kr.',
#   'Move-in price': '58.450 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427388',
#   'Adress': 'Spættevangen, 2635 København, Ishøj  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '108 m²',
#   'Rooms': '4',
#   'Floor': '2nd ',
#   'Furnished': 'Yes',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '15.200 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '30.400 kr.',
#   'Prepaid rent': '15.200 kr.',
#   'Move-in price': '61.800 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5232474',
#   'Adress': 'Alleen, 2770 København, Kastrup  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '96 m²',
#   'Rooms': '4',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '15 April 2024',
#   'Monthly net rent': '13.350 kr.',
#   'Utilities': '1.100 kr.',
#   'Deposit': '40.050 kr.',
#   'Prepaid rent': '13.350 kr.',
#   'Move-in price': '67.850 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427386',
#   'Adress': 'Elektronikvej, 2605 København, Brøndby  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '92 m²',
#   'Rooms': '4',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '15 April 2024',
#   'Monthly net rent': '12.600 kr.',
#   'Utilities': '1.050 kr.',
#   'Deposit': '37.800 kr.',
#   'Prepaid rent': '12.600 kr.',
#   'Move-in price': '64.050 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5393802',
#   'Adress': 'Mekanikvej, 2605 København, Brøndby  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '106 m²',
#   'Rooms': '3',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '30 June 2024',
#   'Monthly net rent': '18.800 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '56.400 kr.',
#   'Prepaid rent': '18.800 kr.',
#   'Move-in price': '95.000 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427385',
#   'Adress': 'Howitzvej, 2000 København, Frederiksberg  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '167 m²',
#   'Rooms': '5',
#   'Floor': '4th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '30.617 kr.',
#   'Utilities': '1.029 kr.',
#   'Deposit': '91.851 kr.',
#   'Prepaid rent': '30.617 kr.',
#   'Move-in price': '154.114 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427378',
#   'Adress': 'Nørrebrogade, 2200 København, København N  - 4th floor'},
#  {'Property type': 'Apartment',
#   'Size': '117 m²',
#   'Rooms': '5',
#   'Floor': '-',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 August 2024',
#   'Monthly net rent': '17.800 kr.',
#   'Utilities': '1.200 kr.',
#   'Deposit': '53.400 kr.',
#   'Prepaid rent': '17.800 kr.',
#   'Move-in price': '90.200 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5071527',
#   'Adress': 'Falkonergårdsvej, 1959 København, Frederiksberg C '},
#  {'Property type': 'Apartment',
#   'Size': '94 m²',
#   'Rooms': '4',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'No',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 April 2024',
#   'Monthly net rent': '12.500 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '37.500 kr.',
#   'Prepaid rent': '12.500 kr.',
#   'Move-in price': '63.500 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '4906233',
#   'Adress': 'Sporstræde, 2640 København, Hedehusene  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '86 m²',
#   'Rooms': '2',
#   'Floor': '5th ',
#   'Furnished': 'Yes',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '',
#   'Rental period': '24+ months',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '19.950 kr.',
#   'Utilities': '900 kr.',
#   'Deposit': '59.850 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '80.700 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427351',
#   'Adress': 'Nørre Farimagsgade, 1364 København, København K  - 5th floor'},
#  {'Property type': 'Apartment',
#   'Size': '121 m²',
#   'Rooms': '4',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'Not specified',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'No',
#   'Parking': 'Not specified',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '15 April 2024',
#   'Monthly net rent': '19.700 kr.',
#   'Utilities': '900 kr.',
#   'Deposit': '59.100 kr.',
#   'Prepaid rent': '39.400 kr.',
#   'Move-in price': '119.100 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427367',
#   'Adress': 'Enghavevej, 2100 København, København Ø  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '133 m²',
#   'Rooms': '5',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'No',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '17.850 kr.',
#   'Utilities': '1.565 kr.',
#   'Deposit': '53.550 kr.',
#   'Prepaid rent': '17.850 kr.',
#   'Move-in price': '90.815 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5281373',
#   'Adress': 'Rubinolavej, 2500 København, Valby  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '80 m²',
#   'Rooms': '2',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'Yes',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 May 2024',
#   'Monthly net rent': '13.995 kr.',
#   'Utilities': '850 kr.',
#   'Deposit': '41.985 kr.',
#   'Prepaid rent': '13.995 kr.',
#   'Move-in price': '70.825 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5222631',
#   'Adress': 'Amager Strandvej, 2300 København, København S  - 3rd floor'},
#  {'Property type': 'Room',
#   'Size': '14 m²',
#   'Rooms': '1',
#   'Floor': '-',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Not specified',
#   'Senior friendly': 'No',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '5.500 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '11.000 kr.',
#   'Prepaid rent': '5.500 kr.',
#   'Move-in price': '22.000 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '4060832',
#   'Adress': 'Havrens Kvt, 2620 København, Albertslund '},
#  {'Property type': 'Room',
#   'Size': '31 m²',
#   'Rooms': '1',
#   'Floor': '4th ',
#   'Furnished': 'Yes',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': '1-11 months',
#   'Available from': '1 April 2024',
#   'Monthly net rent': '8.500 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '8.500 kr.',
#   'Prepaid rent': '8.500 kr.',
#   'Move-in price': '25.500 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5427350',
#   'Adress': 'Nørrebrogade, 2200 København, København N  - 4th floor'},
#  {'Property type': 'Apartment',
#   'Size': '146 m²',
#   'Rooms': '3',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': '12-23 months',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '28.500 kr.',
#   'Utilities': '1.300 kr.',
#   'Deposit': '85.500 kr.',
#   'Prepaid rent': '28.500 kr.',
#   'Move-in price': '143.800 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5378258',
#   'Adress': 'Frederiksberg Alle, 1820 København, Frederiksberg C  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '84 m²',
#   'Rooms': '3',
#   'Floor': '1st ',
#   'Furnished': 'Yes',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '',
#   'Rental period': '24+ months',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '12.500 kr.',
#   'Utilities': '1.500 kr.',
#   'Deposit': '25.000 kr.',
#   'Prepaid rent': '12.500 kr.',
#   'Move-in price': '51.500 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '5152888',
#   'Adress': 'Stubmøllevej, 2450 København, København SV  - 1st floor'},
#  {'Property type': 'Room',
#   'Size': '15 m²',
#   'Rooms': '1',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '4.500 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '4.500 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '9.000 kr.',
#   'Creation Date': '21/03/2024',
#   'Listing-id': '4407771',
#   'Adress': 'Parkstykket, 2700 København, Brønshøj  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '76 m²',
#   'Rooms': '2',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
# ...
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5361143',
#   'Adress': 'Telegrafvej, 2750 København, Ballerup  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '36 m²',
#   'Rooms': '1',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'Yes',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '15 May 2024',
#   'Monthly net rent': '5.195 kr.',
#   'Utilities': '450 kr.',
#   'Deposit': '15.585 kr.',
#   'Prepaid rent': '5.195 kr.',
#   'Move-in price': '26.425 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5335509',
#   'Adress': 'Telegrafvej, 2750 København, Ballerup  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '113 m²',
#   'Rooms': '3',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 April 2024',
#   'Monthly net rent': '13.995 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '41.985 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '42.785 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5423672',
#   'Adress': 'Bagsværd Hovedgade, 2880 København, Bagsværd  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '67 m²',
#   'Rooms': '2',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '9.975 kr.',
#   'Utilities': '450 kr.',
#   'Deposit': '29.925 kr.',
#   'Prepaid rent': '9.975 kr.',
#   'Move-in price': '50.325 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '3529195',
#   'Adress': 'Berings Gade, 2630 København, Taastrup  - 1st floor'},
#  {'Property type': 'Room',
#   'Size': '10 m²',
#   'Rooms': '1',
#   'Floor': '7th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': '1-11 months',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '6.000 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '18.000 kr.',
#   'Prepaid rent': '18.000 kr.',
#   'Move-in price': '42.800 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5423509',
#   'Adress': 'Strandlodsvej, 2300 København, København S  - 7th floor'},
#  {'Property type': 'Room',
#   'Size': '11 m²',
#   'Rooms': '1',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '5.300 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '10.600 kr.',
#   'Prepaid rent': '5.300 kr.',
#   'Move-in price': '21.200 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5423513',
#   'Adress': 'Himmerlandsvej, 2720 København, Vanløse  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '58 m²',
#   'Rooms': '2',
#   'Floor': 'Ground floor',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': '12-23 months',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '12.500 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '37.500 kr.',
#   'Prepaid rent': '12.500 kr.',
#   'Move-in price': '63.500 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5384596',
#   'Adress': 'Sundkaj, 2150 København, Nordhavn  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '29 m²',
#   'Rooms': '1',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '7.950 kr.',
#   'Utilities': '500 kr.',
#   'Deposit': '23.850 kr.',
#   'Prepaid rent': '7.950 kr.',
#   'Move-in price': '40.250 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5423636',
#   'Adress': 'Strynøgade, 2100 København, København Ø  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '108 m²',
#   'Rooms': '3',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 May 2024',
#   'Monthly net rent': '16.285 kr.',
#   'Utilities': '1.320 kr.',
#   'Deposit': '48.855 kr.',
#   'Prepaid rent': '16.285 kr.',
#   'Move-in price': '82.745 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5176804',
#   'Adress': 'Axel Heides Gade, 2300 København, København S  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '119 m²',
#   'Rooms': '4',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '17.150 kr.',
#   'Utilities': '1.450 kr.',
#   'Deposit': '51.450 kr.',
#   'Prepaid rent': '17.150 kr.',
#   'Move-in price': '87.200 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5400323',
#   'Adress': 'Linde Allé, 2720 København, Vanløse  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '67 m²',
#   'Rooms': '2',
#   'Floor': '5th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '14 June 2024',
#   'Monthly net rent': '13.200 kr.',
#   'Utilities': '750 kr.',
#   'Deposit': '39.600 kr.',
#   'Prepaid rent': '13.200 kr.',
#   'Move-in price': '66.750 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5423632',
#   'Adress': 'Ingrid Marievej, 2500 København, Valby  - 5th floor'},
#  {'Property type': 'Apartment',
#   'Size': '31 m²',
#   'Rooms': '1',
#   'Floor': '5th ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '30 June 2024',
#   'Monthly net rent': '8.450 kr.',
#   'Utilities': '400 kr.',
#   'Deposit': '25.350 kr.',
#   'Prepaid rent': '8.450 kr.',
#   'Move-in price': '42.650 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5423631',
#   'Adress': 'Henriette Crones Gade, 2450 København, København SV  - 5th floor'},
#  {'Property type': 'Apartment',
#   'Size': '72 m²',
#   'Rooms': '2',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': '24+ months',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '13.750 kr.',
#   'Utilities': '600 kr.',
#   'Deposit': '41.250 kr.',
#   'Prepaid rent': '13.750 kr.',
#   'Move-in price': '69.350 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5423566',
#   'Adress': 'Ordrupvej, 2920 København, Charlottenlund  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '40 m²',
#   'Rooms': '1',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '8.395 kr.',
#   'Utilities': '500 kr.',
#   'Deposit': '25.185 kr.',
#   'Prepaid rent': '8.395 kr.',
#   'Move-in price': '42.475 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5362914',
#   'Adress': 'Smedetoften, 2400 København, København NV  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '69 m²',
#   'Rooms': '1',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '10.495 kr.',
#   'Utilities': '584 kr.',
#   'Deposit': '31.485 kr.',
#   'Prepaid rent': '10.495 kr.',
#   'Move-in price': '53.059 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5423565',
#   'Adress': 'Banegårdspladsen, 2750 København, Ballerup  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '114 m²',
#   'Rooms': '3',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '22.995 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '68.985 kr.',
#   'Prepaid rent': '22.995 kr.',
#   'Move-in price': '115.775 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5275411',
#   'Adress': 'Martinsvej, 1926 København, Frederiksberg C  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '33 m²',
#   'Rooms': '1',
#   'Floor': '20th ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 May 2024',
#   'Monthly net rent': '9.800 kr.',
#   'Utilities': '798 kr.',
#   'Deposit': '19.600 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '30.198 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5423540',
#   'Adress': 'Dybbølsbro, 1577 København, København V  - 20th floor'},
#  {'Property type': 'Apartment',
#   'Size': '33 m²',
#   'Rooms': '1',
#   'Floor': '8th ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '15 April 2024',
#   'Monthly net rent': '10.200 kr.',
#   'Utilities': '798 kr.',
#   'Deposit': '20.400 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '31.398 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5423536',
#   'Adress': 'Dybbølsbro, 1577 København, København V  - 8th floor'},
#  {'Property type': 'Apartment',
#   'Size': '33 m²',
#   'Rooms': '1',
#   'Floor': '12th ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '15 April 2024',
#   'Monthly net rent': '9.300 kr.',
#   'Utilities': '798 kr.',
#   'Deposit': '18.600 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '28.698 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5423534',
#   'Adress': 'Dybbølsbro, 1577 København, København V  - 12th floor'},
#  {'Property type': 'Apartment',
#   'Size': '33 m²',
#   'Rooms': '1',
#   'Floor': '10th ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '15 April 2024',
#   'Monthly net rent': '9.300 kr.',
#   'Utilities': '798 kr.',
#   'Deposit': '18.600 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '28.698 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5423531',
#   'Adress': 'Dybbølsbro, 1577 København, København V  - 10th floor'},
#  {'Property type': 'Apartment',
#   'Size': '50 m²',
#   'Rooms': '2',
#   'Floor': '12th ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': '12-23 months',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '9.000 kr.',
#   'Utilities': '750 kr.',
#   'Deposit': '18.000 kr.',
#   'Prepaid rent': '9.000 kr.',
#   'Move-in price': '36.750 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5029450',
#   'Adress': 'Bagsværd Hovedgade, 2880 København, Bagsværd  - 12th floor'},
#  {'Property type': 'Apartment',
#   'Size': '31 m²',
#   'Rooms': '1',
#   'Floor': '1st ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '30 June 2024',
#   'Monthly net rent': '8.150 kr.',
#   'Utilities': '400 kr.',
#   'Deposit': '24.450 kr.',
#   'Prepaid rent': '8.150 kr.',
#   'Move-in price': '41.150 kr.',
#   'Creation Date': '04/03/2024',
#   'Listing-id': '5423518',
#   'Adress': 'Henriette Crones Gade, 2450 København, København SV  - 1st floor'},
#  ...]

# %% [markdown]
# # Load data to a dataframe

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      Property type    Size Rooms         Floor Furnished Shareable  \
# 0        Apartment  100 m²     4  Ground floor        No       Yes
# 1        Apartment  154 m²     5          1st         No        No
# 2        Apartment   54 m²     2  Ground floor        No        No
# 3        Apartment   71 m²     3          5th         No       Yes
# 4        Apartment   63 m²     2          4th         No       Yes
# ...            ...     ...   ...           ...       ...       ...
# 2736     Apartment   55 m²     2  Ground floor       Yes        No
# 2737          Room   15 m²     1          3rd        Yes       Yes
# 2738     Apartment  125 m²     3          4th        Yes       Yes
# 2739          Room   22 m²     1          4th        Yes        No
# 2740          Room   10 m²     1          4th        Yes        No
#
#      Pets allowed       Elevator Senior friendly  Students only  ...  \
# 0              No             No              No             No  ...
# 1              No             No              No             No  ...
# 2              No             No              No             No  ...
# 3             Yes            Yes              No             No  ...
# 4             Yes            Yes              No             No  ...
# ...           ...            ...             ...            ...  ...
# 2736           No             No             Yes             No  ...
# 2737          Yes             No              No             No  ...
# 2738           No             No              No             No  ...
# 2739           No  Not specified   Not specified  Not specified  ...
# 2740           No            Yes             Yes             No  ...
#
#      Rental period       Available from Monthly net rent  Utilities  \
# 0      1-11 months     1 September 2024       22.000 kr.      0 kr.
# 1        Unlimited           1 May 2024       23.000 kr.  1.400 kr.
# 2        Unlimited  As soon as possible        8.448 kr.    410 kr.
# 3        Unlimited  As soon as possible       14.300 kr.    700 kr.
# 4        Unlimited  As soon as possible       12.700 kr.    650 kr.
# ...            ...                  ...              ...        ...
# 2736   1-11 months         15 July 2024       14.000 kr.      0 kr.
# 2737   1-11 months        14 April 2024        8.000 kr.      0 kr.
# 2738   1-11 months  As soon as possible       30.000 kr.      0 kr.
# 2739    24+ months  As soon as possible        3.800 kr.      0 kr.
# 2740   1-11 months  As soon as possible        3.999 kr.      0 kr.
#
#          Deposit Prepaid rent Move-in price Creation Date Listing-id  \
# 0     22.000 kr.   22.000 kr.    66.000 kr.    21/03/2024    5427722
# 1     69.000 kr.   69.000 kr.   162.400 kr.    21/03/2024    5427716
# 2     25.344 kr.   25.344 kr.    59.546 kr.    21/03/2024    5427711
# 3     42.900 kr.   14.300 kr.    72.200 kr.    21/03/2024    5427710
# 4     38.100 kr.   12.700 kr.    64.150 kr.    21/03/2024    5427709
# ...          ...          ...           ...           ...        ...
# 2736   2.000 kr.        0 kr.    16.000 kr.    27/12/2021    5218308
# 2737  10.000 kr.        0 kr.    18.000 kr.    17/07/2021    5091127
# 2738  10.000 kr.        0 kr.    40.000 kr.    07/07/2021    5204260
# 2739   7.600 kr.    3.800 kr.    15.200 kr.    29/10/2020    5024726
# 2740       0 kr.        0 kr.     3.999 kr.    31/08/2020    4927519
#
#                                                  Adress
# 0     Løgstørgade, 2100 København, København Ø  - Gr...
# 1     Virginiavej, 2000 København, Frederiksberg  - ...
# 2     Ellensvej, 2920 København, Charlottenlund  - G...
# 3     Martha Christensens Vej, 2300 København, Køben...
# 4     Martha Christensens Vej, 2300 København, Køben...
# ...                                                 ...
# 2736  Hedemannsgade, 2100 København, København Ø  - ...
# 2737  Marstalsgade, 2100 København, København Ø  - 3...
# 2738  Arkonagade, 1726 København, København V  - 4th...
# 2739  Jagtvej, 2100 København, København Ø  - 4th floor
# 2740  Gyngemose Parkvej, 2860 København, Søborg  - 4...
#
# [2741 rows x 27 columns]

# %%
df.to_csv('ads_data.csv')

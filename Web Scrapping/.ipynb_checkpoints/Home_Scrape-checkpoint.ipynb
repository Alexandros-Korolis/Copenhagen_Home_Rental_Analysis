# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm

# %%
# Define target url. Search for houses in Copenhagen and surroundings, boligtype = Rent
url = "https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/"
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text,'html.parser')

# %% [markdown]
# # Get pagination links

# %%
# There are 153 pages, starting from index page 1
pagination_html = soup.find('div',{'class':'css-95dbty'}).find_all('button',{'class':'temporaryButtonClassname'})
for i in range(len(pagination_html)):
    print(pagination_html[i].get_text())
# Out:
# 1
# 2
# 3
# 4
# 5
# 111

# %%
# We can see that when we choose the 2nd page then the offset attribute in the url changes 2nd page -> offset = 18 (or [2-1]*18,
# 3rd page -> offset = 36 (or [3-1]*18) etc)

# %%
links_of_pages = []
for i in range(1,int(pagination_html[-1].get_text())+1):
    if i == 1:
        links_of_pages.append('https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/')
    else:
        links_of_pages.append('https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset={}'.format((i-1)*18))

# %%
links_of_pages
# Out:
# ['https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=18',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=36',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=54',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=72',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=90',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=108',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=126',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=144',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=162',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=180',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=198',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=216',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=234',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=252',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=270',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=288',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=306',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=324',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=342',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=360',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=378',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=396',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=414',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=432',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=450',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=468',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=486',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=504',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=522',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=540',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=558',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=576',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=594',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=612',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=630',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=648',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=666',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=684',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=702',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=720',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=738',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=756',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=774',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=792',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=810',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=828',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=846',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=864',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=882',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=900',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=918',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=936',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=954',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=972',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=990',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1008',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1026',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1044',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1062',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1080',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1098',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1116',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1134',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1152',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1170',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1188',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1206',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1224',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1242',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1260',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1278',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1296',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1314',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1332',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1350',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1368',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1386',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1404',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1422',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1440',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1458',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1476',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1494',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1512',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1530',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1548',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1566',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1584',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1602',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1620',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1638',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1656',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1674',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1692',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1710',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1728',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1746',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1764',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1782',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1800',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1818',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1836',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1854',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1872',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1890',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1908',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1926',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1944',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1962',
#  'https://www.boligportal.dk/en/rental-properties/k%C3%B8benhavn/?offset=1980']

# %% [markdown]
# # Get links of ads in first page

# %%
# first page contains 18 ads 
first_page_ads = soup.find_all('div',{'class':'css-7r8xmo'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-nkly31'})
len(first_page_ads)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23356\1872894930.py in <cell line: 2>()
#       1 # first page contains 18 ads
# ----> 2 first_page_ads = soup.find_all('div',{'class':'css-7r8xmo'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-nkly31'})
#       3 len(first_page_ads)
#
# IndexError: list index out of range

# %%
soup.find_all('div',{'class':'css-7r8xmo'})[1].find_all('div',{'class':'temporaryFlexColumnClassName css-nkly31'})[0].find('div',{'class':'css-m2wmpr'}).find('a')['href']
# Out:
# '/en/rental-apartments/k%C3%B8benhavn/100m2-4-room-id-5216044'

# %%
first_page_links = []
for i in range(len(first_page_ads)):
    first_page_links.append('https://www.boligportal.dk{}'.format(first_page_ads[i].find('div',{'class':'css-m2wmpr'}).find('a')['href']))

# %%
first_page_links
# Out:
# ['https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/100m2-4-room-id-5216044',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/84m2-3-room-id-5242890',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/115m2-5-room-id-5430086',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/58m2-2-room-id-5414477',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/92m2-4-room-id-5344440',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/155m2-4-room-id-5276450',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/55m2-2-room-id-5430114',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/63m2-2-room-id-5430113',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/103m2-4-room-id-5047279',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/63m2-2-room-id-5422366',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/60m2-2-room-id-5260320',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/25m2-1-room-id-5430105',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/56m2-2-room-id-5430104',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/31m2-1-room-id-5430101',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/73m2-2-room-id-5430098',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/106m2-4-room-id-3098826',
#  'https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/88m2-2-room-id-5234141',
#  'https://www.boligportal.dk/en/rental-houses/k%C3%B8benhavn/158m2-5-room-id-5430082']

# %% [markdown]
# # Lets get the links of all ads across all pages

# %%
# So, now we have to iterate through links_of_pages list, connect to each link and get its links.

# %%
all_ads_links = []
for link in tqdm(links_of_pages):
    url = link
    response = requests.get(url)
    soup = BeautifulSoup(response.text,'html.parser')
    page_ads = soup.find_all('div',{'class':'css-7r8xmo'})[1].find_all('div',{'class':'temporaryFlexColumnClassName css-nkly31'})
    for i in range(len(page_ads)):
        all_ads_links.append('https://www.boligportal.dk{}'.format(page_ads[i].find('div',{'class':'css-m2wmpr'}).find('a')['href']))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 152/152 [01:26<00:00,  1.75it/s]

# %%
len(all_ads_links)
# Out:
# 2732

# %% [markdown]
# # Get data

# %%
# Now I have to connect to each link from above and get the data that I need. 
# Store them in a dictionary and append them in a list . 
# Should look like this [{home1:id},{home2:id}, etc]

# %%
#########

# %%
url = "https://www.boligportal.dk/en/rental-apartments/k%C3%B8benhavn/96m2-2-room-id-5427607"
response = requests.get(url)
soup = BeautifulSoup(response.text,'html.parser')

# %%
# adress
soup.find_all('div',{'class':'css-1gjufnd'})[0].find('div',{'class':'css-o9y6d5'}).get_text()
# Out:
# 'Nordmarks Alle, 2620 København, Albertslund  - 2nd floor'

# %%
# About property 
about_property = soup.find_all('section',{'class':'css-6tqm96'})[0]

# %%
# Property tpy
about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[0].find('div',{'class':'css-6tqm96'}).get_text()
# Out:
# 'Property type'

# %%
about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[0].find('div',{'class':'css-5fqrc1'}).get_text()
# Out:
# 'Apartment'

# %%
lst1 = []
lst2 = []
for i in range(len(about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'}))):
    lst1.append(about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-6tqm96'}).get_text())
    lst2.append(about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-5fqrc1'}).get_text())
    new = dict(zip(lst1,lst2))

# %%
new
# Out:
# {'Property type': 'Apartment',
#  'Size': '96 m²',
#  'Rooms': '2',
#  'Floor': '2nd ',
#  'Furnished': 'No',
#  'Shareable': 'No',
#  'Pets allowed': 'Yes',
#  'Elevator': 'Yes',
#  'Senior friendly': 'Not specified',
#  'Students only': 'Not specified',
#  'Balcony': 'Yes',
#  'Parking': 'Not specified',
#  'Dishwasher': 'Not specified',
#  'Washing machine': 'Not specified',
#  'Electric charging station': 'No',
#  'Dryer': 'Not specified',
#  'Energy rating': '-'}

# %%
# About rental 
about_rental = soup.find_all('section',{'class':'css-6tqm96'})[1]

# %%
about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[0].find('div',{'class':'css-6tqm96'}).get_text()
# Out:
# 'Rental period'

# %%
about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[0].find('div',{'class':'css-5fqrc1'}).get_text()
# Out:
# 'Unlimited'

# %%
lst2 = []
lst3 = []
for i in range(len(about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'}))):
    lst2.append(about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-6tqm96'}).get_text())
    lst3.append(about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-5fqrc1'}).get_text())
    new1 = dict(zip(lst2,lst3))

# %%
new1
# Out:
# {'Rental period': 'Unlimited',
#  'Available from': 'As soon as possible',
#  'Monthly net rent': '12.400 kr.',
#  'Deposit': '37.200 kr.',
#  'Prepaid rent': '12.400 kr.',
#  'Move-in price': '62.000 kr.',
#  'Creation Date': '21/03/2024',
#  'Listing-id': '5427607'}

# %%
new.update(new1)

# %%
new['Adress'] = soup.find_all('div',{'class':'css-1gjufnd'})[0].find('div',{'class':'css-o9y6d5'}).get_text()

# %%
new
# Out:
# {'Property type': 'Apartment',
#  'Size': '96 m²',
#  'Rooms': '2',
#  'Floor': '2nd ',
#  'Furnished': 'No',
#  'Shareable': 'No',
#  'Pets allowed': 'Yes',
#  'Elevator': 'Yes',
#  'Senior friendly': 'Not specified',
#  'Students only': 'Not specified',
#  'Balcony': 'Yes',
#  'Parking': 'Not specified',
#  'Dishwasher': 'Not specified',
#  'Washing machine': 'Not specified',
#  'Electric charging station': 'No',
#  'Dryer': 'Not specified',
#  'Energy rating': '-',
#  'Rental period': 'Unlimited',
#  'Available from': 'As soon as possible',
#  'Monthly net rent': '12.400 kr.',
#  'Deposit': '37.200 kr.',
#  'Prepaid rent': '12.400 kr.',
#  'Move-in price': '62.000 kr.',
#  'Creation Date': '21/03/2024',
#  'Listing-id': '5427607',
#  'Adress': 'Nordmarks Alle, 2620 København, Albertslund  - 2nd floor'}

# %%
# Now I have to connect to each link from above and get the data that I need. 
# Store them in a dictionary and append them in a list . 
# Should look like this [{home1:id},{home2:id}, etc]

# %%
def get_data(link):
    prop_key = []
    prop_value = []
    rental_key = []
    rental_value = []
    properties = {}
    rental_features = {}
    
    url = link
    response = requests.get(url)
    soup = BeautifulSoup(response.text,'html.parser')
    about_property = soup.find_all('section',{'class':'css-6tqm96'})[0]
    about_rental = soup.find_all('section',{'class':'css-6tqm96'})[1]

    for i in range(len(about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'}))):
        prop_key.append(about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-6tqm96'}).get_text())
        prop_value.append(about_property.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-5fqrc1'}).get_text())
        properties = dict(zip(prop_key,prop_value))

    for i in range(len(about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'}))):
        rental_key.append(about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-6tqm96'}).get_text())
        rental_value.append(about_rental.find_all('div',{'class':'css-1f8ckkp'})[0].find_all('div',{'class':'temporaryFlexColumnClassName css-1ksgrzt'})[i].find('div',{'class':'css-5fqrc1'}).get_text())
        rental_features = dict(zip(rental_key,rental_value))
    properties.update(rental_features)
    properties['Adress'] = soup.find_all('div',{'class':'css-1gjufnd'})[0].find('div',{'class':'css-o9y6d5'}).get_text()
    return properties

# %%
data = [] 
for link in tqdm(all_ads_links):
    data.append(get_data(link))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2732/2732 [19:07<00:00,  2.38it/s]

# %%
data
# Out:
# [{'Property type': 'Apartment',
#   'Size': '100 m²',
#   'Rooms': '4',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'No',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '18.500 kr.',
#   'Utilities': '850 kr.',
#   'Deposit': '55.500 kr.',
#   'Prepaid rent': '55.500 kr.',
#   'Move-in price': '130.350 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5216044',
#   'Adress': 'Ejgårdsvej, 2920 København, Charlottenlund  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '84 m²',
#   'Rooms': '3',
#   'Floor': '3rd ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'No',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': '24+ months',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '15.000 kr.',
#   'Deposit': '45.000 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '60.000 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5242890',
#   'Adress': 'Sølvgade, 1307 København, København K  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '115 m²',
#   'Rooms': '5',
#   'Floor': 'Ground floor',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': '12-23 months',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '36.000 kr.',
#   'Utilities': '3.000 kr.',
#   'Deposit': '108.000 kr.',
#   'Prepaid rent': '108.000 kr.',
#   'Move-in price': '255.000 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430086',
#   'Adress': 'Holbergsgade, 1057 København, København K  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '58 m²',
#   'Rooms': '2',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '30 June 2024',
#   'Monthly net rent': '10.300 kr.',
#   'Utilities': '700 kr.',
#   'Deposit': '30.900 kr.',
#   'Prepaid rent': '10.300 kr.',
#   'Move-in price': '52.200 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5414477',
#   'Adress': 'Fjerkløvervej, 2750 København, Ballerup  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '92 m²',
#   'Rooms': '4',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '30 June 2024',
#   'Monthly net rent': '18.200 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '54.600 kr.',
#   'Prepaid rent': '18.200 kr.',
#   'Move-in price': '92.000 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5344440',
#   'Adress': 'Amerikavej, 1756 København, København V  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '155 m²',
#   'Rooms': '4',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '22.950 kr.',
#   'Utilities': '1.010 kr.',
#   'Deposit': '68.850 kr.',
#   'Prepaid rent': '22.950 kr.',
#   'Move-in price': '115.760 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5276450',
#   'Adress': 'Omøgade, 2100 København, København Ø  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '55 m²',
#   'Rooms': '2',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '15 June 2024',
#   'Monthly net rent': '9.500 kr.',
#   'Utilities': '500 kr.',
#   'Deposit': '28.500 kr.',
#   'Prepaid rent': '9.500 kr.',
#   'Move-in price': '48.000 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430114',
#   'Adress': 'Dagmarhaven, 2665 København, Vallensbæk Strand  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '63 m²',
#   'Rooms': '2',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '10.650 kr.',
#   'Utilities': '700 kr.',
#   'Deposit': '31.950 kr.',
#   'Prepaid rent': '10.650 kr.',
#   'Move-in price': '53.950 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430113',
#   'Adress': 'Skolebakken, 2640 København, Hedehusene  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '103 m²',
#   'Rooms': '4',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '13.500 kr.',
#   'Utilities': '1.200 kr.',
#   'Deposit': '40.500 kr.',
#   'Prepaid rent': '13.500 kr.',
#   'Move-in price': '68.700 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5047279',
#   'Adress': 'Eigtveds Alle, 2630 København, Taastrup  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '63 m²',
#   'Rooms': '2',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '9.500 kr.',
#   'Utilities': '650 kr.',
#   'Deposit': '28.500 kr.',
#   'Prepaid rent': '9.500 kr.',
#   'Move-in price': '48.150 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5422366',
#   'Adress': 'Ballerup Boulevard, 2740 København, Skovlunde  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '60 m²',
#   'Rooms': '2',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '15 May 2024',
#   'Monthly net rent': '11.000 kr.',
#   'Utilities': '650 kr.',
#   'Deposit': '33.000 kr.',
#   'Prepaid rent': '11.000 kr.',
#   'Move-in price': '55.650 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5260320',
#   'Adress': 'Doris Lessings Vej, 2300 København, København S  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '25 m²',
#   'Rooms': '1',
#   'Floor': '4th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '31 May 2024',
#   'Monthly net rent': '7.900 kr.',
#   'Utilities': '750 kr.',
#   'Deposit': '23.700 kr.',
#   'Prepaid rent': '7.900 kr.',
#   'Move-in price': '40.250 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430105',
#   'Adress': 'Finsensvej, 2000 København, Frederiksberg  - 4th floor'},
#  {'Property type': 'Apartment',
#   'Size': '56 m²',
#   'Rooms': '2',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 September 2024',
#   'Monthly net rent': '9.500 kr.',
#   'Utilities': '500 kr.',
#   'Deposit': '28.500 kr.',
#   'Prepaid rent': '9.500 kr.',
#   'Move-in price': '48.000 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430104',
#   'Adress': 'Vejlesvinget, 2665 København, Vallensbæk Strand  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '31 m²',
#   'Rooms': '1',
#   'Floor': '-',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '30 June 2024',
#   'Monthly net rent': '7.675 kr.',
#   'Utilities': '350 kr.',
#   'Deposit': '23.025 kr.',
#   'Prepaid rent': '7.675 kr.',
#   'Move-in price': '38.725 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430101',
#   'Adress': 'Sigurdsgade, 2200 København, København N '},
#  {'Property type': 'Apartment',
#   'Size': '73 m²',
#   'Rooms': '2',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '17.000 kr.',
#   'Utilities': '900 kr.',
#   'Deposit': '51.000 kr.',
#   'Prepaid rent': '17.000 kr.',
#   'Move-in price': '85.900 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430098',
#   'Adress': 'Judithsvej, 2900 København, Hellerup  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '106 m²',
#   'Rooms': '4',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Not specified',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '17.500 kr.',
#   'Utilities': '900 kr.',
#   'Deposit': '52.500 kr.',
#   'Prepaid rent': '52.500 kr.',
#   'Move-in price': '123.400 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '3098826',
#   'Adress': 'Tranevej, 2400 København, København NV  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '88 m²',
#   'Rooms': '2',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '12.900 kr.',
#   'Utilities': '660 kr.',
#   'Deposit': '32.700 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '46.260 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5234141',
#   'Adress': 'Søborg Hovedgade, 2860 København, Søborg  - 3rd floor'},
#  {'Property type': 'House',
#   'Size': '158 m²',
#   'Rooms': '5',
#   'Floor': '-',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': '12-23 months',
#   'Available from': '1 May 2024',
#   'Monthly net rent': '21.500 kr.',
#   'Utilities': '2.500 kr.',
#   'Deposit': '64.500 kr.',
#   'Prepaid rent': '21.500 kr.',
#   'Move-in price': '110.000 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430082',
#   'Adress': 'Kulsviervej, 2800 København, Kongens Lyngby '},
#  {'Property type': 'House',
#   'Size': '158 m²',
#   'Rooms': '5',
#   'Floor': '-',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': '12-23 months',
#   'Available from': '1 May 2024',
#   'Monthly net rent': '21.500 kr.',
#   'Utilities': '2.500 kr.',
#   'Deposit': '64.500 kr.',
#   'Prepaid rent': '21.500 kr.',
#   'Move-in price': '110.000 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430082',
#   'Adress': 'Kulsviervej, 2800 København, Kongens Lyngby '},
#  {'Property type': 'Apartment',
#   'Size': '81 m²',
#   'Rooms': '3',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 January 2025',
#   'Monthly net rent': '10.950 kr.',
#   'Utilities': '1.100 kr.',
#   'Deposit': '32.850 kr.',
#   'Prepaid rent': '10.950 kr.',
#   'Move-in price': '55.850 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5397333',
#   'Adress': 'Urtehaven, 2640 København, Hedehusene  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '65 m²',
#   'Rooms': '2',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '30 June 2024',
#   'Monthly net rent': '10.400 kr.',
#   'Utilities': '850 kr.',
#   'Deposit': '31.200 kr.',
#   'Prepaid rent': '10.400 kr.',
#   'Move-in price': '52.850 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '4982089',
#   'Adress': 'Mekanikvej, 2605 København, Brøndby  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '69 m²',
#   'Rooms': '2',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 June 2024',
#   'Monthly net rent': '10.495 kr.',
#   'Utilities': '584 kr.',
#   'Deposit': '31.485 kr.',
#   'Prepaid rent': '10.495 kr.',
#   'Move-in price': '53.059 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430076',
#   'Adress': 'Banegårdspladsen, 2750 København, Ballerup  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '57 m²',
#   'Rooms': '2',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '10.000 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '30.000 kr.',
#   'Prepaid rent': '10.000 kr.',
#   'Move-in price': '50.800 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430073',
#   'Adress': 'Gyngemose Parkvej, 2860 København, Søborg  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '56 m²',
#   'Rooms': '3',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '11.000 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '33.000 kr.',
#   'Prepaid rent': '11.000 kr.',
#   'Move-in price': '55.800 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430072',
#   'Adress': 'Gyngemose Parkvej, 2860 København, Søborg  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '57 m²',
#   'Rooms': '3',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '10.800 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '32.400 kr.',
#   'Prepaid rent': '10.800 kr.',
#   'Move-in price': '54.800 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430071',
#   'Adress': 'Gyngemose Parkvej, 2860 København, Søborg  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '33 m²',
#   'Rooms': '1',
#   'Floor': '3rd ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '9.000 kr.',
#   'Utilities': '400 kr.',
#   'Deposit': '18.000 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '27.400 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430062',
#   'Adress': 'Hejrevej, 2400 København, København NV  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '35 m²',
#   'Rooms': '1',
#   'Floor': '5th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '9.200 kr.',
#   'Utilities': '400 kr.',
#   'Deposit': '18.400 kr.',
#   'Prepaid rent': '9.200 kr.',
#   'Move-in price': '37.200 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430061',
#   'Adress': 'Hejrevej, 2400 København, København NV  - 5th floor'},
#  {'Property type': 'Apartment',
#   'Size': '63 m²',
#   'Rooms': '2',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '15 May 2024',
#   'Monthly net rent': '11.200 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '33.600 kr.',
#   'Prepaid rent': '11.200 kr.',
#   'Move-in price': '56.800 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5279646',
#   'Adress': 'Skanørgade, 2630 København, Taastrup  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '39 m²',
#   'Rooms': '1',
#   'Floor': '1st ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '9.600 kr.',
#   'Utilities': '400 kr.',
#   'Deposit': '19.200 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '29.200 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430058',
#   'Adress': 'Hejrevej, 2400 København, København NV  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '68 m²',
#   'Rooms': '2',
#   'Floor': '4th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '15 June 2024',
#   'Monthly net rent': '13.600 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '40.800 kr.',
#   'Prepaid rent': '13.600 kr.',
#   'Move-in price': '68.800 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '4091198',
#   'Adress': 'Øresundsvej, 2300 København, København S  - 4th floor'},
#  {'Property type': 'Apartment',
#   'Size': '118 m²',
#   'Rooms': '4',
#   'Floor': '4th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'No',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '15.600 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '46.800 kr.',
#   'Prepaid rent': '15.600 kr.',
#   'Move-in price': '79.000 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430066',
#   'Adress': 'Asger Jorns Allé, 2300 København, København S  - 4th floor'},
#  {'Property type': 'Apartment',
#   'Size': '67 m²',
#   'Rooms': '2',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'No',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '12.200 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '36.600 kr.',
#   'Prepaid rent': '12.200 kr.',
#   'Move-in price': '61.800 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430065',
#   'Adress': 'Robert Jacobsens Vej, 2300 København, København S  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '95 m²',
#   'Rooms': '4',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '13.200 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '39.600 kr.',
#   'Prepaid rent': '13.200 kr.',
#   'Move-in price': '67.000 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430064',
#   'Adress': 'Rønnebygade, 2630 København, Taastrup  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '60 m²',
#   'Rooms': '2',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '10.100 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '30.300 kr.',
#   'Prepaid rent': '10.100 kr.',
#   'Move-in price': '51.300 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5279652',
#   'Adress': 'Skanørgade, 2630 København, Taastrup  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '101 m²',
#   'Rooms': '4',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '15.700 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '47.100 kr.',
#   'Prepaid rent': '15.700 kr.',
#   'Move-in price': '79.500 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5091057',
#   'Adress': 'Else Alfelts Vej, 2300 København, København S  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '77 m²',
#   'Rooms': '2',
#   'Floor': '5th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '12.500 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '37.500 kr.',
#   'Prepaid rent': '12.500 kr.',
#   'Move-in price': '63.300 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '4943022',
#   'Adress': 'Hannemanns Allé, 2300 København, København S  - 5th floor'},
#  {'Property type': 'Apartment',
#   'Size': '90 m²',
#   'Rooms': '2',
#   'Floor': '8th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '13.500 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '40.500 kr.',
#   'Prepaid rent': '13.500 kr.',
#   'Move-in price': '68.500 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '4691041',
#   'Adress': 'Hannemanns Allé, 2300 København, København S  - 8th floor'},
#  {'Property type': 'Apartment',
#   'Size': '97 m²',
#   'Rooms': '3',
#   'Floor': '8th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '14.400 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '43.200 kr.',
#   'Prepaid rent': '14.400 kr.',
#   'Move-in price': '73.000 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '4089474',
#   'Adress': 'Else Alfelts Vej, 2300 København, København S  - 8th floor'},
#  {'Property type': 'Apartment',
#   'Size': '97 m²',
#   'Rooms': '3',
#   'Floor': '9th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '14.800 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '44.400 kr.',
#   'Prepaid rent': '14.800 kr.',
#   'Move-in price': '75.000 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5127313',
#   'Adress': 'Else Alfelts Vej, 2300 København, København S  - 9th floor'},
#  {'Property type': 'Apartment',
#   'Size': '83 m²',
#   'Rooms': '3',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '12.200 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '36.600 kr.',
#   'Prepaid rent': '12.200 kr.',
#   'Move-in price': '62.000 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '4904996',
#   'Adress': 'Skjeberg Allé, 2630 København, Taastrup  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '73 m²',
#   'Rooms': '3',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '11.900 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '35.700 kr.',
#   'Prepaid rent': '11.900 kr.',
#   'Move-in price': '60.300 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '4640269',
#   'Adress': 'Skjeberg Allé, 2630 København, Taastrup  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '99 m²',
#   'Rooms': '4',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'No',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '12.700 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '38.100 kr.',
#   'Prepaid rent': '12.700 kr.',
#   'Move-in price': '64.500 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '4826518',
#   'Adress': 'Sporstræde, 2640 København, Hedehusene  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '58 m²',
#   'Rooms': '2',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'No',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '9.400 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '28.200 kr.',
#   'Prepaid rent': '9.400 kr.',
#   'Move-in price': '47.800 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '4796139',
#   'Adress': 'Sporstræde, 2640 København, Hedehusene  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '35 m²',
#   'Rooms': '1',
#   'Floor': '5th ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '9.200 kr.',
#   'Utilities': '400 kr.',
#   'Deposit': '18.400 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '28.000 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430056',
#   'Adress': 'Hejrevej, 2400 København, København NV  - 5th floor'},
#  {'Property type': 'Apartment',
#   'Size': '35 m²',
#   'Rooms': '1',
#   'Floor': '6th ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '9.300 kr.',
#   'Utilities': '400 kr.',
#   'Deposit': '18.600 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '28.300 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430054',
#   'Adress': 'Hejrevej, 2400 København, København NV  - 6th floor'},
#  {'Property type': 'Apartment',
#   'Size': '35 m²',
#   'Rooms': '1',
#   'Floor': '6th ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '9.300 kr.',
#   'Utilities': '400 kr.',
#   'Deposit': '18.600 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '28.300 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430053',
#   'Adress': 'Hejrevej, 2400 København, København NV  - 6th floor'},
#  {'Property type': 'Apartment',
#   'Size': '30 m²',
#   'Rooms': '1',
#   'Floor': '6th ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '8.700 kr.',
#   'Utilities': '400 kr.',
#   'Deposit': '17.400 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '26.500 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430052',
#   'Adress': 'Hejrevej, 2400 København, København NV  - 6th floor'},
#  {'Property type': 'Apartment',
#   'Size': '39 m²',
#   'Rooms': '1',
#   'Floor': '5th ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': '12-23 months',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '9.900 kr.',
#   'Utilities': '400 kr.',
#   'Deposit': '19.800 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '30.100 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430050',
#   'Adress': 'Hejrevej, 2400 København, København NV  - 5th floor'},
#  {'Property type': 'Apartment',
#   'Size': '113 m²',
#   'Rooms': '5',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '16.800 kr.',
#   'Utilities': '1.750 kr.',
#   'Deposit': '50.400 kr.',
#   'Prepaid rent': '16.800 kr.',
#   'Move-in price': '85.750 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5348308',
#   'Adress': 'Else Alfelts Vej, 2300 København, København S  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '70 m²',
#   'Rooms': '3',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '12.400 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '37.200 kr.',
#   'Prepaid rent': '12.400 kr.',
#   'Move-in price': '62.800 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5169511',
#   'Adress': 'C. F. Møllers Allé, 2300 København, København S  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '78 m²',
#   'Rooms': '3',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '12.750 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '38.250 kr.',
#   'Prepaid rent': '12.750 kr.',
#   'Move-in price': '64.550 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5191235',
#   'Adress': 'Halldór Laxness Vej, 2300 København, København S  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '109 m²',
#   'Rooms': '4',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '14.200 kr.',
#   'Utilities': '1.200 kr.',
#   'Deposit': '42.600 kr.',
#   'Prepaid rent': '14.200 kr.',
#   'Move-in price': '72.200 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '4262503',
#   'Adress': 'Emma Gads Vej, 2300 København, København S  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '127 m²',
#   'Rooms': '5',
#   'Floor': '4th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '16.800 kr.',
#   'Utilities': '1.400 kr.',
#   'Deposit': '50.400 kr.',
#   'Prepaid rent': '16.800 kr.',
#   'Move-in price': '85.400 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '4844434',
#   'Adress': 'Halldor Laxness Vej, 2300 København, København S  - 4th floor'},
#  {'Property type': 'Apartment',
#   'Size': '72 m²',
#   'Rooms': '3',
#   'Floor': '2nd ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'No',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': '24+ months',
#   'Available from': '15 April 2024',
#   'Monthly net rent': '16.700 kr.',
#   'Utilities': '850 kr.',
#   'Deposit': '50.100 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '67.650 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430049',
#   'Adress': 'Sølvgade, 1307 København, København K  - 2nd floor'},
#  {'Property type': 'Room',
#   'Size': '12 m²',
#   'Rooms': '1',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 May 2024',
#   'Monthly net rent': '6.000 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '6.000 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '12.000 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430030',
#   'Adress': 'Værnedamsvej, 1819 København, Frederiksberg C  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '89 m²',
#   'Rooms': '4',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '30 June 2024',
#   'Monthly net rent': '13.100 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '39.300 kr.',
#   'Prepaid rent': '13.100 kr.',
#   'Move-in price': '66.500 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5241593',
#   'Adress': 'Mekanikvej, 2605 København, Brøndby  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '56 m²',
#   'Rooms': '1',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '11.000 kr.',
#   'Utilities': '650 kr.',
#   'Deposit': '33.000 kr.',
#   'Prepaid rent': '11.000 kr.',
#   'Move-in price': '55.650 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430046',
#   'Adress': 'Amagerfælledvej, 2300 København, København S  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '120 m²',
#   'Rooms': '4',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '16.000 kr.',
#   'Utilities': '1.250 kr.',
#   'Deposit': '48.000 kr.',
#   'Prepaid rent': '16.000 kr.',
#   'Move-in price': '81.250 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5193775',
#   'Adress': 'Amagerfælledvej, 2300 København, København S  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '100 m²',
#   'Rooms': '3',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '14.600 kr.',
#   'Utilities': '1.140 kr.',
#   'Deposit': '43.800 kr.',
#   'Prepaid rent': '14.600 kr.',
#   'Move-in price': '74.140 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430045',
#   'Adress': 'Amagerfælledvej, 2300 København, København S  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '78 m²',
#   'Rooms': '3',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '15 April 2024',
#   'Monthly net rent': '10.920 kr.',
#   'Utilities': '995 kr.',
#   'Deposit': '32.760 kr.',
#   'Prepaid rent': '10.920 kr.',
#   'Move-in price': '55.595 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5430033',
#   'Adress': 'Parkstrøget, 2630 København, Taastrup  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '87 m²',
#   'Rooms': '3',
#   'Floor': '4th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '14.900 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '44.700 kr.',
#   'Prepaid rent': '14.900 kr.',
#   'Move-in price': '75.500 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '5046623',
#   'Adress': 'Strandlodsvej, 2300 København, København S  - 4th floor'},
#  {'Property type': 'Apartment',
#   'Size': '88 m²',
#   'Rooms': '3',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '16.300 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '48.900 kr.',
#   'Prepaid rent': '16.300 kr.',
#   'Move-in price': '82.500 kr.',
#   'Creation Date': '04/04/2024',
#   'Listing-id': '4512192',
#   'Adress': 'Havneholmen, 2450 København, København SV  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '103 m²',
#   'Rooms': '3',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 August 2024',
#   'Monthly net rent': '15.400 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '46.200 kr.',
#   'Prepaid rent': '15.400 kr.',
#   'Move-in price': '78.000 kr.',
#   'Creation Date': '04/04/2024',
# ...
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '30 June 2024',
#   'Monthly net rent': '11.372 kr.',
#   'Utilities': '1.044 kr.',
#   'Deposit': '34.116 kr.',
#   'Prepaid rent': '34.116 kr.',
#   'Move-in price': '80.648 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5425782',
#   'Adress': 'Skanderupvej, 2610 København, Rødovre  - 1st floor'},
#  {'Property type': 'Room',
#   'Size': '16 m²',
#   'Rooms': '1',
#   'Floor': 'Ground floor',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '6.200 kr.',
#   'Utilities': '300 kr.',
#   'Deposit': '10.000 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '16.500 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5267008',
#   'Adress': 'Kong Oscars Gade, 2100 København, København Ø  - Ground floor'},
#  {'Property type': 'Apartment',
#   'Size': '29 m²',
#   'Rooms': '1',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'No',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'No',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '31 May 2024',
#   'Monthly net rent': '7.900 kr.',
#   'Utilities': '600 kr.',
#   'Deposit': '23.700 kr.',
#   'Prepaid rent': '7.900 kr.',
#   'Move-in price': '40.100 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5332264',
#   'Adress': 'Poul Bundgaards Vej, 2500 København, Valby  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '149 m²',
#   'Rooms': '4',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '14 June 2024',
#   'Monthly net rent': '29.900 kr.',
#   'Utilities': '1.650 kr.',
#   'Deposit': '89.700 kr.',
#   'Prepaid rent': '29.900 kr.',
#   'Move-in price': '151.150 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5050246',
#   'Adress': 'Tuborg Bakkedrag, 2900 København, Hellerup  - 1st floor'},
#  {'Property type': 'House',
#   'Size': '175 m²',
#   'Rooms': '4',
#   'Floor': '-',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Not specified',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Not specified',
#   'Parking': 'Not specified',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'No',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': '24+ months',
#   'Available from': '1 May 2024',
#   'Monthly net rent': '38.000 kr.',
#   'Utilities': '1.500 kr.',
#   'Deposit': '114.000 kr.',
#   'Move-in price': '153.500 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5306909',
#   'Adress': 'lemchesvej, 2900 København, Hellerup '},
#  {'Property type': 'Apartment',
#   'Size': '77 m²',
#   'Rooms': '3',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '31 May 2024',
#   'Monthly net rent': '12.200 kr.',
#   'Utilities': '850 kr.',
#   'Deposit': '36.600 kr.',
#   'Prepaid rent': '12.200 kr.',
#   'Move-in price': '61.850 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5286771',
#   'Adress': 'Mejsevangen, 2635 København, Ishøj  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '95 m²',
#   'Rooms': '4',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '30 September 2024',
#   'Monthly net rent': '16.700 kr.',
#   'Utilities': '900 kr.',
#   'Deposit': '50.100 kr.',
#   'Prepaid rent': '16.700 kr.',
#   'Move-in price': '84.400 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '4823450',
#   'Adress': 'Thoras Vænge, 2950 København, Vedbæk  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '51 m²',
#   'Rooms': '2',
#   'Floor': '1st ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': '1-11 months',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '10.200 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '30.600 kr.',
#   'Prepaid rent': '10.200 kr.',
#   'Move-in price': '51.800 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5371518',
#   'Adress': 'Århusgade, 2100 København, København Ø  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '59 m²',
#   'Rooms': '2',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '15 April 2024',
#   'Monthly net rent': '8.500 kr.',
#   'Utilities': '500 kr.',
#   'Deposit': '25.000 kr.',
#   'Prepaid rent': '8.500 kr.',
#   'Move-in price': '42.500 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5425742',
#   'Adress': 'Taastrup Have, 2630 København, Taastrup  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '106 m²',
#   'Rooms': '3',
#   'Floor': '5th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Not specified',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'Not specified',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'No',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '22.900 kr.',
#   'Utilities': '1.000 kr.',
#   'Deposit': '68.700 kr.',
#   'Prepaid rent': '68.700 kr.',
#   'Move-in price': '161.300 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '4552815',
#   'Adress': 'Langelands Plads, 2000 København, Frederiksberg  - 5th floor'},
#  {'Property type': 'Apartment',
#   'Size': '92 m²',
#   'Rooms': '4',
#   'Floor': '1st ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Yes',
#   'Dryer': 'Yes',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 May 2024',
#   'Monthly net rent': '13.000 kr.',
#   'Utilities': '1.050 kr.',
#   'Deposit': '39.000 kr.',
#   'Prepaid rent': '13.000 kr.',
#   'Move-in price': '66.050 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5425761',
#   'Adress': 'Mekanikvej, 2605 København, Brøndby  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '101 m²',
#   'Rooms': '4',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'No',
#   'Washing machine': 'No',
#   'Electric charging station': 'No',
#   'Dryer': 'No',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '16.200 kr.',
#   'Utilities': '1.050 kr.',
#   'Deposit': '48.600 kr.',
#   'Prepaid rent': '16.200 kr.',
#   'Move-in price': '82.050 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5425749',
#   'Adress': 'Montagehalsvej, 2500 København, Valby  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '112 m²',
#   'Rooms': '4',
#   'Floor': '5th ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Not specified',
#   'Students only': 'Not specified',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'No',
#   'Dryer': 'Not specified',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '18.700 kr.',
#   'Utilities': '1.200 kr.',
#   'Deposit': '56.100 kr.',
#   'Prepaid rent': '56.100 kr.',
#   'Move-in price': '132.100 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5425739',
#   'Adress': 'Vestre Teglgade, 2450 København, København SV  - 5th floor'},
#  {'Property type': 'Apartment',
#   'Size': '74 m²',
#   'Rooms': '2',
#   'Floor': '2nd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'No',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Not specified',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '10.252 kr.',
#   'Utilities': '900 kr.',
#   'Deposit': '30.756 kr.',
#   'Prepaid rent': '10.252 kr.',
#   'Move-in price': '52.160 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5425686',
#   'Adress': 'Søgræsgade, 2640 København, Hedehusene  - 2nd floor'},
#  {'Property type': 'Apartment',
#   'Size': '100 m²',
#   'Rooms': '2',
#   'Floor': '3rd ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': '12-23 months',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '35.000 kr.',
#   'Utilities': '35.000 kr.',
#   'Deposit': '105.000 kr.',
#   'Prepaid rent': '105.000 kr.',
#   'Move-in price': '280.000 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5425653',
#   'Adress': 'Lille Kongensgade, 1074 København, København K  - 3rd floor'},
#  {'Property type': 'Apartment',
#   'Size': '94 m²',
#   'Rooms': '3',
#   'Floor': '3rd ',
#   'Furnished': 'No',
#   'Shareable': 'No',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Not specified',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Not specified',
#   'Energy rating': '',
#   'Rental period': 'Unlimited',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '14.200 kr.',
#   'Utilities': '750 kr.',
#   'Deposit': '42.600 kr.',
#   'Prepaid rent': '14.200 kr.',
#   'Move-in price': '71.750 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5425632',
#   'Adress': 'Hedesøvej, 2640 København, Hedehusene  - 3rd floor'},
#  {'Property type': 'Room',
#   'Size': '20 m²',
#   'Rooms': '1',
#   'Floor': 'Ground floor',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': '1-11 months',
#   'Available from': '1 May 2024',
#   'Monthly net rent': '6.000 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '18.000 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '24.000 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5425610',
#   'Adress': 'Jægersborg Alle, 2820 København, Gentofte  - Ground floor'},
#  {'Property type': 'Room',
#   'Size': '20 m²',
#   'Rooms': '1',
#   'Floor': '1st ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': '1-11 months',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '6.000 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '18.000 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '24.000 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5425609',
#   'Adress': 'Jægersborg Alle, 2820 København, Gentofte  - 1st floor'},
#  {'Property type': 'Room',
#   'Size': '20 m²',
#   'Rooms': '1',
#   'Floor': '1st ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'Yes',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'No',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': '1-11 months',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '6.000 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '18.000 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '24.000 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5425608',
#   'Adress': 'Jægersborg Alle, 2820 København, Gentofte  - 1st floor'},
#  {'Property type': 'Apartment',
#   'Size': '86 m²',
#   'Rooms': '3',
#   'Floor': '6th ',
#   'Furnished': 'No',
#   'Shareable': 'Yes',
#   'Pets allowed': 'Yes',
#   'Elevator': 'Yes',
#   'Senior friendly': 'Yes',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'No',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': 'Unlimited',
#   'Available from': '1 July 2024',
#   'Monthly net rent': '13.950 kr.',
#   'Utilities': '800 kr.',
#   'Deposit': '41.850 kr.',
#   'Prepaid rent': '13.950 kr.',
#   'Move-in price': '70.550 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5160222',
#   'Adress': 'Robert Jacobsens Vej, 2300 København, København S  - 6th floor'},
#  {'Property type': 'Room',
#   'Size': '25 m²',
#   'Rooms': '1',
#   'Floor': '2nd ',
#   'Furnished': 'Yes',
#   'Shareable': 'No',
#   'Pets allowed': 'No',
#   'Elevator': 'No',
#   'Senior friendly': 'No',
#   'Students only': 'No',
#   'Balcony': 'Yes',
#   'Parking': 'Yes',
#   'Dishwasher': 'Yes',
#   'Washing machine': 'Yes',
#   'Electric charging station': 'Not specified',
#   'Dryer': 'Yes',
#   'Energy rating': '-',
#   'Rental period': '1-11 months',
#   'Available from': 'As soon as possible',
#   'Monthly net rent': '6.500 kr.',
#   'Utilities': '0 kr.',
#   'Deposit': '19.500 kr.',
#   'Prepaid rent': '0 kr.',
#   'Move-in price': '26.000 kr.',
#   'Creation Date': '13/03/2024',
#   'Listing-id': '5425602',
#   'Adress': 'Ermelundsvej, 2820 København, Gentofte  - 2nd floor'},
#  ...]

# %% [markdown]
# # Load data to a dataframe

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      Property type    Size Rooms         Floor Furnished Shareable  \
# 0        Apartment  100 m²     4          2nd         No        No
# 1        Apartment   84 m²     3          3rd        Yes        No
# 2        Apartment  115 m²     5  Ground floor       Yes        No
# 3        Apartment   58 m²     2          2nd         No       Yes
# 4        Apartment   92 m²     4          1st         No       Yes
# ...            ...     ...   ...           ...       ...       ...
# 2727     Apartment   55 m²     2  Ground floor       Yes        No
# 2728          Room   15 m²     1          3rd        Yes       Yes
# 2729     Apartment  125 m²     3          4th        Yes       Yes
# 2730          Room   22 m²     1          4th        Yes        No
# 2731          Room   10 m²     1          4th        Yes        No
#
#      Pets allowed       Elevator Senior friendly  Students only  ...  \
# 0              No             No   Not specified  Not specified  ...
# 1              No             No              No             No  ...
# 2              No             No              No             No  ...
# 3             Yes            Yes             Yes             No  ...
# 4              No            Yes              No             No  ...
# ...           ...            ...             ...            ...  ...
# 2727           No             No             Yes             No  ...
# 2728          Yes             No              No             No  ...
# 2729           No             No              No             No  ...
# 2730           No  Not specified   Not specified  Not specified  ...
# 2731           No            Yes             Yes             No  ...
#
#            Available from Monthly net rent  Utilities      Deposit  \
# 0             1 July 2024       18.500 kr.    850 kr.   55.500 kr.
# 1             1 June 2024       15.000 kr.        NaN   45.000 kr.
# 2     As soon as possible       36.000 kr.  3.000 kr.  108.000 kr.
# 3            30 June 2024       10.300 kr.    700 kr.   30.900 kr.
# 4            30 June 2024       18.200 kr.  1.000 kr.   54.600 kr.
# ...                   ...              ...        ...          ...
# 2727         15 July 2024       14.000 kr.      0 kr.    2.000 kr.
# 2728        14 April 2024        8.000 kr.      0 kr.   10.000 kr.
# 2729  As soon as possible       30.000 kr.      0 kr.   10.000 kr.
# 2730  As soon as possible        3.800 kr.      0 kr.    7.600 kr.
# 2731  As soon as possible        3.999 kr.      0 kr.        0 kr.
#
#      Prepaid rent Move-in price Creation Date Listing-id  \
# 0      55.500 kr.   130.350 kr.    04/04/2024    5216044
# 1           0 kr.    60.000 kr.    04/04/2024    5242890
# 2     108.000 kr.   255.000 kr.    04/04/2024    5430086
# 3      10.300 kr.    52.200 kr.    04/04/2024    5414477
# 4      18.200 kr.    92.000 kr.    04/04/2024    5344440
# ...           ...           ...           ...        ...
# 2727        0 kr.    16.000 kr.    27/12/2021    5218308
# 2728        0 kr.    18.000 kr.    17/07/2021    5091127
# 2729        0 kr.    40.000 kr.    07/07/2021    5204260
# 2730    3.800 kr.    15.200 kr.    29/10/2020    5024726
# 2731        0 kr.     3.999 kr.    31/08/2020    4927519
#
#                                                  Adress Housing deposit
# 0     Ejgårdsvej, 2920 København, Charlottenlund  - ...             NaN
# 1     Sølvgade, 1307 København, København K  - 3rd f...             NaN
# 2     Holbergsgade, 1057 København, København K  - G...             NaN
# 3     Fjerkløvervej, 2750 København, Ballerup  - 2nd...             NaN
# 4     Amerikavej, 1756 København, København V  - 1st...             NaN
# ...                                                 ...             ...
# 2727  Hedemannsgade, 2100 København, København Ø  - ...             NaN
# 2728  Marstalsgade, 2100 København, København Ø  - 3...             NaN
# 2729  Arkonagade, 1726 København, København V  - 4th...             NaN
# 2730  Jagtvej, 2100 København, København Ø  - 4th floor             NaN
# 2731  Gyngemose Parkvej, 2860 København, Søborg  - 4...             NaN
#
# [2732 rows x 28 columns]

# %%
df.to_csv('ads_data.csv',index=False)
